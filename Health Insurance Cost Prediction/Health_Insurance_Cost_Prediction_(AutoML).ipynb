# %%
# !pip install pycaret

# %%
from pycaret.utils import version
version()
# Out:
# '3.3.2'

# %% [markdown]
# from pycaret.datasets import get_data
# get_data('indecx'

# %%
from pycaret.datasets import get_data
dataset = get_data('index')
# Out:
#                              Dataset    Data Types  \
# 0                            anomaly  Multivariate
# 1                             france  Multivariate
# 2                            germany  Multivariate
# 3                               bank  Multivariate
# 4                              blood  Multivariate
# 5                             cancer  Multivariate
# 6                             credit  Multivariate
# 7                           diabetes  Multivariate
# 8                    electrical_grid  Multivariate
# 9                           employee  Multivariate
# 10                             heart  Multivariate
# 11                     heart_disease  Multivariate
# 12                         hepatitis  Multivariate
# 13                            income  Multivariate
# 14                             juice  Multivariate
# 15                               nba  Multivariate
# 16                              wine  Multivariate
# ...

# %%
data = get_data('insurance')
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
from pycaret.regression import *
s = setup(data = data, target= 'charges',train_size=0.7)
# Out:
# <style type="text/css">
# #T_bf964_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_bf964" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bf964_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_bf964_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bf964_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_bf964_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_bf964_row0_col1" class="data row0 col1" >212</td>
#     </tr>
#     <tr>
#       <th id="T_bf964_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_bf964_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_bf964_row1_col1" class="data row1 col1" >charges</td>
#     </tr>
#     <tr>
#       <th id="T_bf964_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
cm = compare_models()
# Out:
# <style type="text/css">
# #T_331a9 th {
#   text-align: left;
# }
# ...

# %%
from pycaret.datasets import get_data
from pycaret.regression import *

dataset = get_data('insurance')
s= setup(data = dataset, target='charges')
cm= compare_models()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520
# <style type="text/css">
# #T_de900_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_de900" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_de900_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_de900_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_de900_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_de900_row0_col0" class="data row0 col0" >Session id</td>
# ...

# %%
from pycaret.datasets import get_data
from pycaret.regression import *

data = get_data('insurance')
s=setup(data=data,target='charges')
model = create_model('gbr')
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520
# <style type="text/css">
# #T_8b3a5_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_8b3a5" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8b3a5_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_8b3a5_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8b3a5_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8b3a5_row0_col0" class="data row0 col0" >Session id</td>
# ...

# %%
sm = save_model(model, 'model_save_grb')
# Out:
# Transformation Pipeline and Model Successfully Saved

# %%
model = load_model('model_save_grb')
# Out:
# Transformation Pipeline and Model Successfully Loaded

# %%
import pandas as pd

data = {'age':40, 'sex':1, 'bmi': 40, 'children':4, 'smoker':1, 'region':2}

df = pd.DataFrame(data,index=[0])
df
# Out:
#    age  sex  bmi  children  smoker  region
# 0   40    1   40         4       1       2

# %%
pred=predict_model(model,df)

# %%
pred
# Out:
#    age  sex  bmi  children  smoker  region  prediction_label
# 0   40    1   40         4       1       2       8578.889544
